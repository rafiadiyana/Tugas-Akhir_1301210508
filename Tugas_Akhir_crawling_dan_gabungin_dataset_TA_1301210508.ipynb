# %% [markdown]
# # Crawl Data Twitter (X)
# The crawling process was done using Tweet-Harvest by Helmi Satria.
#
# https://www.youtube.com/@helmisatria/featured

# %%
#@title Instalasi library

# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [99.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,046 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,307 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,081 kB]
# ...

# %%
# Install dependency Playwright (WAJIB untuk tweet-harvest di Colab)
# !npx playwright install-deps chromium
# !npx playwright install chromium
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙Need to install the following packages:
# playwright@1.61.1
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
#@title Twitter Auth Token

twitter_auth_token = 'f9303a0b9e146bcf50270d859db45a1949c9af13' #masukkan auth_token twitter

# cara mendapatkan auth_token twitten
# 1. Buka X.com dan klik kanan
# 2. Klik inspect
# 3. Pilih bagian application
# 4. Klik auth_token dan copas auth_tokennya

# %%
#@title Crawl Data

filename = 'dataset_kdrt.csv' # nama file
search_keyword = 'kdrt lang:id'
limit = 100 # jumlah tweet yang ingin didapat

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/dataset_kdrt_antiKorban.csv, renaming to ./tweets-data/dataset_kdrt_antiKorban.old.csv
#
# Filling in keywords: kdrt lang:id
#
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/dataset_kdrt_antiKorban.csv
# Total tweets saved: 20
#
#
# Your tweets saved to: /content/tweets-data/dataset_kdrt_antiKorban.csv
# Total tweets saved: 40
#
#
# Your tweets saved to: /content/tweets-data/dataset_kdrt_antiKorban.csv
# Total tweets saved: 60
#
# -- Scrolling... (1) (2)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#     conversation_id_str                      created_at  favorite_count  \
# 0    427607317811834880  Mon Jan 27 01:01:43 +0000 2014               0
# 1    426708973526323200  Fri Jan 24 13:32:01 +0000 2014               0
# 2    426708871797694465  Fri Jan 24 13:31:37 +0000 2014               1
# 3    426383993697599488  Thu Jan 23 16:00:40 +0000 2014               1
# 4    426352757914607616  Thu Jan 23 13:56:33 +0000 2014               0
# ..                  ...                             ...             ...
# 95   400779550121947136  Thu Nov 14 00:17:45 +0000 2013               0
# 96   400637408695156736  Wed Nov 13 14:52:56 +0000 2013               1
# 97   400593899539816448  Wed Nov 13 12:00:02 +0000 2013               0
# 98   400585851828068352  Wed Nov 13 11:28:04 +0000 2013               0
# 99   399827593525870594  Mon Nov 11 09:15:01 +0000 2013               1
#
#                                             full_text              id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 100.

# %%
df.to_csv('kdrt_antiKorban.csv', index=False)

# %%
df2.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1888796814738075737  Mon Feb 10 07:20:48 +0000 2025               1
# 1  1888576482685116721  Mon Feb 10 06:10:22 +0000 2025               0
# 2  1888751710577025168  Mon Feb 10 00:47:53 +0000 2025               1
# 3  1888623007339630784  Sun Feb 09 18:20:57 +0000 2025               0
# 4  1888238506302193755  Sun Feb 09 15:24:19 +0000 2025               4
#
#                                            full_text               id_str  \
# 0  @ken_fullmetal @rommorningstar @mayyypham @vng...  1888850590845092240
# 1  @zachsilver16 @dckyy_mw @itstime4changed @your...  1888832865573712091
# 2  Ada cewe jepang nikah sama cowo irlandia tingg...  1888751710577025168
# 3  @Azer11124 berarti kasus kdrt di perempuan leb...  1888654334554259474
# 4  @abd69650 @apapeduliku313 @kegblgnunfaedh Lapo...  1888609883194286132
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# ...

# %%
df2.tail()
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 637  1741773739216474618  Mon Jan 01 14:33:22 +0000 2024               1
# 638  1741798165718913354  Mon Jan 01 12:26:58 +0000 2024               0
# 639  1741616369962270745  Mon Jan 01 12:04:55 +0000 2024               3
# 640  1741731356756086805  Mon Jan 01 08:01:29 +0000 2024               1
# 641  1741719013582082444  Mon Jan 01 07:41:06 +0000 2024               0
#
#                                              full_text               id_str  \
# 637  @jujukyng Itu cewe selingkuhan mungkin korban ...  1741829973927973231
# 638  Org org indo kalau nanganin per ngeweeean cepe...  1741798165718913354
# 639  @330Thunderbird @xojolx @Beritasatu Istrinya s...  1741792615610376200
# 640  Video Diduga Anggota BNN Aniaya Istri Viral di...  1741731356756086805
# 641  Jadi gimana cara menjadi tetangga yang baik ke...  1741726226883252728
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      539 non-null    int64
#  1   created_at               539 non-null    object
#  2   favorite_count           539 non-null    int64
#  3   full_text                539 non-null    object
#  4   id_str                   539 non-null    int64
#  5   image_url                169 non-null    object
#  6   in_reply_to_screen_name  83 non-null     object
#  7   lang                     539 non-null    object
#  8   location                 391 non-null    object
#  9   quote_count              539 non-null    int64
#  10  reply_count              539 non-null    int64
#  11  retweet_count            539 non-null    int64
#  12  tweet_url                539 non-null    object
#  13  user_id_str              539 non-null    int64
# ...

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df[df['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df[df.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#       conversation_id_str                      created_at  favorite_count  \
# 207  1358742526375522309  Mon Feb 08 12:17:58 +0000 2021               0
# 208  1358751893275762694  Mon Feb 08 12:17:50 +0000 2021               0
# 209  1358742526375522309  Mon Feb 08 12:16:47 +0000 2021               0
# 210  1358751592498008067  Mon Feb 08 12:16:38 +0000 2021               0
# 404   456651626678190080  Thu Apr 17 04:33:26 +0000 2014               0
# 405   446195966438162433  Wed Mar 19 08:06:22 +0000 2014               0
# 516   104855569097179136  Sat Aug 20 10:01:30 +0000 2011               0
# 517   104851795167285250  Sat Aug 20 09:46:30 +0000 2011               0
# 518   104848697375993856  Sat Aug 20 09:34:12 +0000 2011               0
# 521   104847513391083520  Sat Aug 20 09:29:29 +0000 2011               0
# 522   104847428469010432  Sat Aug 20 09:29:09 +0000 2011               0
# ...

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_cleaned = df.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_cleaned[df_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
#  save file to csv

# Assuming df_cleaned is the DataFrame you want to save
df_cleaned.to_csv('cleaned_kdrtBillar.csv', index=False)

# %%
df_cleaned.tail()
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 3072  1852394070376886360  Fri Nov 01 17:36:50 +0000 2024               0
# 3073  1852400803954479506  Fri Nov 01 17:22:22 +0000 2024               0
# 3074  1852384752776393073  Fri Nov 01 17:02:33 +0000 2024               0
# 3075  1852387958734959034  Fri Nov 01 16:31:19 +0000 2024               1
# 3076  1852378500948234691  Fri Nov 01 16:12:18 +0000 2024               0
#
#                                               full_text               id_str  \
# 3072                         @mekbdi Ky abis di kdrt by  1852404446330007901
# 3073                       kangennn goldie si anak kdrt  1852400803954479506
# 3074  Belum lagi klo dapet laki yg tempramental Ga c...  1852395817233199330
# 3075  kesel bngt klo baca cerita istri /seorang ibu ...  1852387958734959034
# 3076                       @KATHYYgr kak... gabole kdrt  1852383170189996283
#
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539 entries, 0 to 538
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  539 non-null    object
#  1   username   539 non-null    object
# dtypes: object(2)
# memory usage: 8.6+ KB

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df_cleaned = df[['full_text', 'username']]

# %%
df_cleaned.to_csv("stopkdrt_bersih.csv")

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df2 = df_cleaned[['full_text', 'username']]

# %%
df1 = pd.read_excel('kdrt1_blmbersih.xlsx')

# %%
df1.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df2.head()
# Out:
#                                            full_text       username
# 0  @ken_fullmetal @rommorningstar @mayyypham @vng...        0xYogaA
# 1  @zachsilver16 @dckyy_mw @itstime4changed @your...    GAdiwansyah
# 2  Ada cewe jepang nikah sama cowo irlandia tingg...  tantan__1go1e
# 3  @Azer11124 berarti kasus kdrt di perempuan leb...       bojackkz
# 4  @abd69650 @apapeduliku313 @kegblgnunfaedh Lapo...       wisnu3ds

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3077 entries, 0 to 3076
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  3070 non-null   object
#  1   username   3077 non-null   object
# dtypes: object(2)
# memory usage: 48.2+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 641 entries, 0 to 640
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  641 non-null    object
#  1   username   641 non-null    object
# dtypes: object(2)
# memory usage: 15.0+ KB

# %%
#  gabungkan data df1 dan df2 ke df baru

# Gabungkan df1 dan df2 menjadi df_baru
df_baru = pd.concat([df1, df2], ignore_index=True)

# Tampilkan beberapa baris pertama dari df_baru
df_baru.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3718 entries, 0 to 3717
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  3711 non-null   object
#  1   username   3718 non-null   object
# dtypes: object(2)
# memory usage: 58.2+ KB

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_baru[df_baru['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#       full_text        username
# 117        NaN          exsyvc
# 462        NaN        dshcubba
# 1175       NaN  controversweet
# 2347       NaN        sibcheng
# 2405       NaN  antipsychaotic
# 2945       NaN    bakuldimsum_
# 2983       NaN        238N0ZZA

# %%
df_baru_cleaned = df_baru.dropna(subset=['full_text'])

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_baru_cleaned[df_baru_cleaned['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_baru_cleaned[df_baru_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#                                                full_text         username
# 111                                                Kdrt      zaleavarraa
# 313                                                KDRT         bitolols
# 328                                                KDRT    lakinyaminami
# 668                                                Kdrt      juliduakali
# 927               @tinklesm Kdrt dan selingkuh tentunya     riyansupyans
# 939               @tinklesm Kdrt dan selingkuh tentunya          threags
# 954   GUYS TOLONG AKUUUU aku mau ngelaporin kaka ipa...    makanapayaena
# 1124            @Sooyawng KDRT KAMU AK LAPOR PULICI LOH      JIMlNXJAMIE
# 1191  @PallakaGO @DS_yantie Lapor sih bisa cuma ngga...     suprayitno_r
# 1383                                               kdrt     adalahpasien
# 1396                                               Kdrt    Rainydayinyou
# ...

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_baru_cleaned = df_baru.drop_duplicates(subset=['full_text'])

# %%
df_baru_cleaned.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df_baru_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3690 entries, 0 to 3717
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  3689 non-null   object
#  1   username   3690 non-null   object
# dtypes: object(2)
# memory usage: 86.5+ KB

# %%
df_baru_cleaned.to_csv('cleaned_kdrtTotal.csv', index=False)

# %%
df3 = pd.read_csv('kdrt (3).csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972 entries, 0 to 971
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      972 non-null    int64
#  1   created_at               972 non-null    object
#  2   favorite_count           972 non-null    int64
#  3   full_text                972 non-null    object
#  4   id_str                   972 non-null    int64
#  5   image_url                43 non-null     object
#  6   in_reply_to_screen_name  643 non-null    object
#  7   lang                     972 non-null    object
#  8   location                 510 non-null    object
#  9   quote_count              972 non-null    int64
#  10  reply_count              972 non-null    int64
#  11  retweet_count            972 non-null    int64
#  12  tweet_url                972 non-null    object
#  13  user_id_str              972 non-null    int64
# ...

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df3[df3['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df3[df3.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#       conversation_id_str                      created_at  favorite_count  \
# 359  1823352855342071901  Tue Aug 13 13:36:11 +0000 2024               0
# 557  1769567701499027957  Mon Mar 18 03:33:11 +0000 2024               0
# 678  1741964067382948037  Mon Jan 01 23:26:12 +0000 2024               0
# 684  1741719013582082444  Mon Jan 01 07:41:06 +0000 2024               0
# 736  1734034289724150145  Mon Dec 11 02:16:06 +0000 2023               0
#
#                                              full_text               id_str  \
# 359  Jangan Takut Melapor Begini Cara Lapor KDRT On...  1823352855342071901
# 557  Jangan Takut Melapor Begini Cara Lapor KDRT On...  1769567701499027957
# 678  Jadi gimana cara menjadi tetangga yang baik ke...  1741964067382948037
# 684  Jadi gimana cara menjadi tetangga yang baik ke...  1741726226883252728
# 736  Jangan Takut Melapor Begini Cara Lapor KDRT On...  1734034289724150145
#
# ...

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df3_cleaned = df3.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df3_cleaned[df3_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
df3_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, 0 to 971
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      969 non-null    int64
#  1   created_at               969 non-null    object
#  2   favorite_count           969 non-null    int64
#  3   full_text                969 non-null    object
#  4   id_str                   969 non-null    int64
#  5   image_url                43 non-null     object
#  6   in_reply_to_screen_name  642 non-null    object
#  7   lang                     969 non-null    object
#  8   location                 507 non-null    object
#  9   quote_count              969 non-null    int64
#  10  reply_count              969 non-null    int64
#  11  retweet_count            969 non-null    int64
#  12  tweet_url                969 non-null    object
#  13  user_id_str              969 non-null    int64
# ...

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df3_fix = df3_cleaned[['full_text', 'username']]

# %%
#  gabungkan data df1 dan df2 ke df baru

# Gabungkan df1 dan df2 menjadi df_baru
df_baru2 = pd.concat([df_baru_cleaned, df3_fix], ignore_index=True)

# Tampilkan beberapa baris pertama dari df_baru
df_baru2.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df_baru2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4659 entries, 0 to 4658
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  4658 non-null   object
#  1   username   4659 non-null   object
# dtypes: object(2)
# memory usage: 72.9+ KB

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_baru2[df_baru2['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#      full_text username
# 117       NaN   exsyvc

# %%
df_total_cleaned = df_baru2.dropna(subset=['full_text'])

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_total_cleaned[df_total_cleaned['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned[df_total_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#                                                full_text         username
# 75          @dearchaniee TLONG BNTU LAPOR AKU KENA KDRT       mognahceah
# 123   Sumpah gue pengen cerita ini bener bener sanga...    Msmoon7343381
# 258   @ramydhia Biar gueh rangkum keluh kesah orang2...       LittleDucx
# 318   Ada istri korban kdrt suami lapor polisi sama ...         ireona29
# 441   TW// KDRT || Bantu Kawal Seorang Dokter di Nga...  bacottetangga__
# ...                                                 ...              ...
# 4368  @limeramen @REP0RT_ID Kdrt sama kekerasan buka...        Scopuvier
# 4369  @jujukyng Itu cewe selingkuhan mungkin korban ...          adefai7
# 4370  Org org indo kalau nanganin per ngeweeean cepe...      kangeskopii
# 4371  @330Thunderbird @xojolx @Beritasatu Istrinya s...     YQianzi68348
# 4372  Video Diduga Anggota BNN Aniaya Istri Viral di...     Alurinfo_Ind
#
# [818 rows x 2 columns]

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_total_cleaned = df_total_cleaned.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned[df_total_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
df_total_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4249 entries, 0 to 4658
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  4249 non-null   object
#  1   username   4249 non-null   object
# dtypes: object(2)
# memory usage: 99.6+ KB

# %%
df_total_cleaned.to_csv('cleaned_kdrtTotal2.csv', index=False)

# %%
df4 = pd.read_csv('kdrt (4).csv')

# %%
df4.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1893369456664957336  Sat Feb 22 18:37:10 +0000 2025               0
# 1  1893138573978919362  Sat Feb 22 17:11:39 +0000 2025               0
# 2  1893298671497740559  Sat Feb 22 13:55:53 +0000 2025               0
# 3  1893266054895321376  Sat Feb 22 13:20:04 +0000 2025               0
# 4  1893274186266624390  Sat Feb 22 12:18:35 +0000 2025              26
#
#                                            full_text               id_str  \
# 0  pernah jd korban kdrt haha dipersulit + diulur...  1893369456664957336
# 1  @Heraloebss Temenku bawa 2 batita dianter adek...  1893347936043426191
# 2  miris bgt yaaaa indon tuh rill ga decent civil...  1893298671497740559
# 3  @geprekalter gue lapor kdrt sendirian ke polse...  1893289655488979009
# 4  &gt; Dijelasin kalo mau visum ntar prosedurnya...  1893274186266624390
#
#   image_url in_reply_to_screen_name lang                    location  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      1498 non-null   int64
#  1   created_at               1498 non-null   object
#  2   favorite_count           1498 non-null   int64
#  3   full_text                1498 non-null   object
#  4   id_str                   1498 non-null   int64
#  5   image_url                77 non-null     object
#  6   in_reply_to_screen_name  1009 non-null   object
#  7   lang                     1498 non-null   object
#  8   location                 805 non-null    object
#  9   quote_count              1498 non-null   int64
#  10  reply_count              1498 non-null   int64
#  11  retweet_count            1498 non-null   int64
#  12  tweet_url                1498 non-null   object
#  13  user_id_str              1498 non-null   int64
# ...

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df4[df4['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df4[df4.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#        conversation_id_str                      created_at  favorite_count  \
# 725   1741964067382948037  Mon Jan 01 23:26:12 +0000 2024               0
# 731   1741719013582082444  Mon Jan 01 07:41:06 +0000 2024               0
# 801   1734034289724150145  Mon Dec 11 02:16:06 +0000 2023               0
# 982   1713772293552513093  Mon Oct 16 04:22:09 +0000 2023               0
# 1141  1701534688123498761  Tue Sep 12 09:54:17 +0000 2023               1
# 1142  1701534584780083258  Tue Sep 12 09:53:52 +0000 2023               1
# 1237  1696192993173356786  Tue Aug 29 07:14:57 +0000 2023               1
# 1238  1696192993173356786  Tue Aug 29 03:25:07 +0000 2023               1
#
#                                               full_text               id_str  \
# 725   Jadi gimana cara menjadi tetangga yang baik ke...  1741964067382948037
# 731   Jadi gimana cara menjadi tetangga yang baik ke...  1741726226883252728
# ...

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df4_cleaned = df4.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df4_cleaned[df4_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
df4_cleaned.to_csv('cleaned_kdrt4.csv', index=False)

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df4_fix = df4_cleaned[['full_text', 'username']]

# %%
df4_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1494 entries, 0 to 1497
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  1494 non-null   object
#  1   username   1494 non-null   object
# dtypes: object(2)
# memory usage: 35.0+ KB

# %%
#  gabungkan data df1 dan df2 ke df baru

# Gabungkan df1 dan df2 menjadi df_baru
df_total_cleaned2 = pd.concat([df_total_cleaned, df4_fix], ignore_index=True)

# Tampilkan beberapa baris pertama dari df_baru
df_total_cleaned2.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_total_cleaned2[df_total_cleaned2['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned2[df_total_cleaned2.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_total_cleaned2 = df_total_cleaned2.drop_duplicates(subset=['full_text'])

# %%
df_total_cleaned2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4983 entries, 0 to 5742
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  4983 non-null   object
#  1   username   4983 non-null   object
# dtypes: object(2)
# memory usage: 116.8+ KB

# %%
df_total_cleaned2.to_csv('cleaned_kdrtTotal3.csv', index=False)

# %%
df5 = pd.read_csv('kdrt (5).csv')

# %%
df5.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1893369456664957336  Sat Feb 22 18:37:10 +0000 2025               0
# 1  1893138573978919362  Sat Feb 22 17:11:39 +0000 2025               0
# 2  1893298671497740559  Sat Feb 22 13:55:53 +0000 2025               0
# 3  1893266054895321376  Sat Feb 22 13:20:04 +0000 2025               0
# 4  1893274186266624390  Sat Feb 22 12:18:35 +0000 2025              26
#
#                                            full_text               id_str  \
# 0  pernah jd korban kdrt haha dipersulit + diulur...  1893369456664957336
# 1  @Heraloebss Temenku bawa 2 batita dianter adek...  1893347936043426191
# 2  miris bgt yaaaa indon tuh rill ga decent civil...  1893298671497740559
# 3  @geprekalter gue lapor kdrt sendirian ke polse...  1893289655488979009
# 4  &gt; Dijelasin kalo mau visum ntar prosedurnya...  1893274186266624390
#
#   image_url in_reply_to_screen_name lang                    location  \
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      114 non-null    int64
#  1   created_at               114 non-null    object
#  2   favorite_count           114 non-null    int64
#  3   full_text                114 non-null    object
#  4   id_str                   114 non-null    int64
#  5   image_url                6 non-null      object
#  6   in_reply_to_screen_name  70 non-null     object
#  7   lang                     114 non-null    object
#  8   location                 65 non-null     object
#  9   quote_count              114 non-null    int64
#  10  reply_count              114 non-null    int64
#  11  retweet_count            114 non-null    int64
#  12  tweet_url                114 non-null    object
#  13  user_id_str              114 non-null    int64
# ...

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df5[df5['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df5[df5.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
df4_cleaned.to_csv('cleaned_kdrt4.csv', index=False)

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df5_fix = df5[['full_text', 'username']]

# %%
df5_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  114 non-null    object
#  1   username   114 non-null    object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
#  gabungkan data df1 dan df2 ke df baru

# Gabungkan df1 dan df2 menjadi df_baru
df_total_cleaned3 = pd.concat([df_total_cleaned2, df5_fix], ignore_index=True)

# Tampilkan beberapa baris pertama dari df_baru
df_total_cleaned3.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df_total_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5097 entries, 0 to 5096
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  5097 non-null   object
#  1   username   5097 non-null   object
# dtypes: object(2)
# memory usage: 79.8+ KB

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_total_cleaned3[df_total_cleaned3['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned3[df_total_cleaned3.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#                                                full_text      username
# 3084            Wkwkwk saya lapor kak seto kalau kdrt.   crewSEONGHWA
# 3085  @ayangmu_ Update kondisi pelaku kdrt. Hampir p...  dragsystemtt
# 3086  @ayangmu_ Buat kalian para istri kamu itu puny...  overlinesart
# 3087  @law20956 @Pakbhabin_id @PoldaMetro @ListyoSig...        rvviz7
# 3088  @Pakbhabin_id @PoldaMetro @ListyoSigitP @ahrie...      law20956
# ...                                                 ...           ...
# 5092  @HaubAkalam @txtmustikajaya @ZoneVenomWar Ini ...  PriaPemurung
# 5093  @detikcom Kek kasus seorang istri kena KDRT. U...   rahadyan999
# 5094  Benci banget sama orang2 kayak gitu. Giliran k...   beemydarlin
# 5095  @langilea8 @RidhaIntifadha Ya bnr perkara nnti...    stanza7777
# 5096  @Mata_Netizen62 @__AnakKolong @Anak__Ogi @LexW...   MujiAfianto
#
# [196 rows x 2 columns]

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_total_cleaned3 = df_total_cleaned3.drop_duplicates(subset=['full_text'])

# %%
df_total_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4999 entries, 0 to 5057
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  4999 non-null   object
#  1   username   4999 non-null   object
# dtypes: object(2)
# memory usage: 117.2+ KB

# %%
df_total_cleaned3.to_csv('cleaned_kdrtTotal3.csv', index=False)

# %%
df6 = pd.read_csv('kdrt (6).csv')

# %%
df6.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1897344948237951389  Thu Mar 06 11:09:50 +0000 2025               0
# 1  1897054600685146483  Wed Mar 05 04:26:03 +0000 2025               0
# 2  1897091861334118496  Wed Mar 05 01:08:40 +0000 2025               1
# 3  1896324135044915233  Mon Mar 03 03:53:08 +0000 2025               3
# 4  1896130299735724368  Sun Mar 02 09:55:26 +0000 2025               0
#
#                                            full_text               id_str  \
# 0             @Kayyisaaaaaa klo kena kdrt hrus lapor  1897605538923655385
# 1  @salsatrash Yg begini harus lapor kesiapa ya? ...  1897141533348126957
# 2  Bbrp tahun lalu temn ada yg jd korban kdrt lap...  1897091861334118496
# 3  @txtdrimedia Bukan Ngadu ke Polisi Warga Lapor...  1896408473484853609
# 4  @maapgmain Kalau lapor polisi sertakan bukti K...  1896137262108401723
#
#   image_url in_reply_to_screen_name lang                  location  \
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      210 non-null    int64
#  1   created_at               210 non-null    object
#  2   favorite_count           210 non-null    int64
#  3   full_text                210 non-null    object
#  4   id_str                   210 non-null    int64
#  5   image_url                8 non-null      object
#  6   in_reply_to_screen_name  140 non-null    object
#  7   lang                     210 non-null    object
#  8   location                 116 non-null    object
#  9   quote_count              210 non-null    int64
#  10  reply_count              210 non-null    int64
#  11  retweet_count            210 non-null    int64
#  12  tweet_url                210 non-null    object
#  13  user_id_str              210 non-null    int64
# ...

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df6[df6['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df6[df6.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#      conversation_id_str                      created_at  favorite_count  \
# 3   1896324135044915233  Mon Mar 03 03:53:08 +0000 2025               3
# 5   1894268609100485063  Sun Mar 02 03:09:07 +0000 2025               0
# 21  1894268609100485063  Tue Feb 25 07:27:51 +0000 2025               4
# 36  1893499611161207010  Sun Feb 23 04:37:29 +0000 2025               8
#
#                                             full_text               id_str  \
# 3   @txtdrimedia Bukan Ngadu ke Polisi Warga Lapor...  1896408473484853609
# 5   @Heraloebss Bukan Ngadu ke Polisi Warga Lapor ...  1896035009842331684
# 21  @Heraloebss Bukan Ngadu ke Polisi Warga Lapor ...  1894288183715930428
# 36  @txtdrimedia Bukan Ngadu ke Polisi Warga Lapor...  1893520534367060395
#
#    image_url in_reply_to_screen_name lang     location  quote_count  \
# 3        NaN             txtdrimedia   in  iNews Tower            0
# ...

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df6_cleaned = df6.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df6_cleaned[df6_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [conversation_id_str, created_at, favorite_count, full_text, id_str, image_url, in_reply_to_screen_name, lang, location, quote_count, reply_count, retweet_count, tweet_url, user_id_str, username]
# Index: []

# %%
df4_cleaned.to_csv('cleaned_kdrt4.csv', index=False)

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df6_fix = df6_cleaned[['full_text', 'username']]

# %%
df6_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, 0 to 209
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  208 non-null    object
#  1   username   208 non-null    object
# dtypes: object(2)
# memory usage: 4.9+ KB

# %%
#  gabungkan data df1 dan df2 ke df baru

# Gabungkan df1 dan df2 menjadi df_baru
df_total_cleaned4 = pd.concat([df_total_cleaned3, df6_fix], ignore_index=True)

# Tampilkan beberapa baris pertama dari df_baru
df_total_cleaned4.head()
# Out:
#                                            full_text    username
# 0                      @isbellaruby @ycbennette kdrt  prengutJJH
# 1  Menikah adalah hal yang baik. Konsekuensinya a...  ruangtahul
# 2  @SitiMelyanaaa pelaku kdrt ini keknya bisa dip...   XANOSHITA
# 3  @ngemtot @iamoneofwan Solusi tolol! Pantesan l...   ShinFa_04
# 4  @ngemtot Sewajarnya itu ambigu loh bocil norma...   ShinFa_04

# %%
df_total_cleaned4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5207 entries, 0 to 5206
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  5207 non-null   object
#  1   username   5207 non-null   object
# dtypes: object(2)
# memory usage: 81.5+ KB

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df_total_cleaned4[df_total_cleaned4['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned4[df_total_cleaned4.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#                                                full_text         username
# 75          @dearchaniee TLONG BNTU LAPOR AKU KENA KDRT       mognahceah
# 122   Sumpah gue pengen cerita ini bener bener sanga...    Msmoon7343381
# 257   @ramydhia Biar gueh rangkum keluh kesah orang2...       LittleDucx
# 317   Ada istri korban kdrt suami lapor polisi sama ...         ireona29
# 440   TW// KDRT || Bantu Kawal Seorang Dokter di Nga...  bacottetangga__
# ...                                                 ...              ...
# 5202  @zoelfick Bangsatnya polisi kalo nerima lapora...        EldiRizky
# 5203  viralin aja nder terus lapor ke provos minta t...         citaboon
# 5204  @koyengggg99 @9Uy10j1gB2 @Dededarmamuh Ya emg ...          maeka31
# 5205  @Metro_TV Nah udah paling bener ini nerima sis...       pandAE86__
# 5206  Harusnya sbg pasangan yg sah dimata hukum &amp...    skysbluepiece
#
# [342 rows x 2 columns]

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_total_cleaned4 = df_total_cleaned4.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_total_cleaned4[df_total_cleaned4.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
df_total_cleaned4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5036 entries, 0 to 5094
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  5036 non-null   object
#  1   username   5036 non-null   object
# dtypes: object(2)
# memory usage: 118.0+ KB

# %%
df_total_cleaned4.to_csv('cleaned_kdrtTotal4.csv', index=False)

# %%
df = pd.read_csv('cleaned_kdrtBillar.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4969 entries, 0 to 4968
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      4969 non-null   int64
#  1   created_at               4969 non-null   object
#  2   favorite_count           4969 non-null   int64
#  3   full_text                4969 non-null   object
#  4   id_str                   4969 non-null   int64
#  5   image_url                763 non-null    object
#  6   in_reply_to_screen_name  149 non-null    object
#  7   lang                     4969 non-null   object
#  8   location                 3555 non-null   object
#  9   quote_count              4969 non-null   int64
#  10  reply_count              4969 non-null   int64
#  11  retweet_count            4969 non-null   int64
#  12  tweet_url                4969 non-null   object
#  13  user_id_str              4969 non-null   int64
# ...

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df_fix = df[['full_text', 'username']]

# %%
df_fix.head()
# Out:
#                                            full_text         username
# 0  @bacottetangga__ Lesti Part 2 ? Kalau gatau ke...      RizkyBillar
# 1  @ozarangkuti Anagram dari bola biliar adalah r...      eericcyrill
# 2  oke guys mungkin banyak yang bakal bilang kasu...  claraaulia63094
# 3  Masih Ingat Kasus Rizky Billar yang Cekik dan ...        tvOneNews
# 4  @kegblgnunfaedh Udah selingkuh sama cewek lain...    ferry_krnwn16

# %%
df_fix.tail()
# Out:
#                                               full_text        username
# 4964  Kronologi Lesty Kejora Diduga Jadi Korban KDRT...  cianjurekspres
# 4965  Sudah Anggap Lesti Kejora sebagai Anak Inul Da...       Gorajuara
# 4966  Diterpa Kabar KDRT Ramalan Mbak You Soal Rumah...  paragramberita
# 4967  Duh! Padahal Selalu Terlihat Mesra Lesti Kejor...       Gorajuara
# 4968  Heboh! Mbak You Pernah Meramal Nasib Lesti Seb...     fajaronline

# %%
df_fix.to_csv('cleaned_kdrtBillarBersih.csv', index=False)

# %%
df = pd.read_csv("stopkdrt.csv")

# %%
#  drop semua kolom kecuali full_text dan username pada df_cleaned

df = df[['full_text', 'username']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  435 non-null    object
#  1   username   435 non-null    object
# dtypes: object(2)
# memory usage: 6.9+ KB

# %%
# Memeriksa apakah ada nilai NaN dalam kolom 'full_text'
nan_rows = df[df['full_text'].isna()]
print("Baris dengan nilai NaN di kolom 'full_text':\n", nan_rows)
# Out:
# Baris dengan nilai NaN di kolom 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df[df.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#                                               full_text        username
# 16   Armor Toreador Divonis 4 5 Tahun Penjara atas ...  officialinews_
# 36   Armor Toreador Divonis 4 5 Tahun Penjara atas ...  officialinews_
# 254  BREAKING NEWS: Armor Toreador Suami Cut Intan ...    RyanRafael37
# 260  BREAKING NEWS: Armor Toreador Suami Cut Intan ...       rafmaull_

# %%
# Menghapus baris duplikat berdasarkan kolom 'full_text'
df_cleaned = df.drop_duplicates(subset=['full_text'])

# %%
# Memeriksa duplikat berdasarkan kolom 'full_text'
duplicates = df_cleaned[df_cleaned.duplicated(subset=['full_text'], keep=False)]
print("Duplikat berdasarkan 'full_text':\n", duplicates)
# Out:
# Duplikat berdasarkan 'full_text':
#  Empty DataFrame
# Columns: [full_text, username]
# Index: []

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 433 entries, 0 to 434
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  433 non-null    object
#  1   username   433 non-null    object
# dtypes: object(2)
# memory usage: 10.1+ KB

# %%
#  save file to csv

# Assuming df_cleaned is the DataFrame you want to save
df_cleaned.to_csv('cleaned_cutIntanKdrt.csv', index=False)
